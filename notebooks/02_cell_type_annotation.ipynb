# %% [markdown]
# # Robust Cell Type Signature Scoring
#
# **Dataset**: 10x Genomics Visium - Human Breast Cancer
# **Goal**: Automated spatial signature scoring using `sc.tl.score_genes`
#
# ---
#
# ## Why Signature Scoring?
#
# Visium spots (55µm) contain multiple cells (bulk RNA mixtures). Using single-cell classification models (like CellTypist) on bulk spots forces the model to misclassify the mixture as a single "dominant" type, destroying the ability to detect biologically mixed spots (e.g., tumor-immune interfaces).
#
# A more scientifically robust approach is to evaluate gene signatures across Visium spots using `sc.tl.score_genes`. This models relative enrichment and correctly captures intra-spot mixing.

# %%
import warnings
warnings.filterwarnings('ignore')

import scanpy as sc
import squidpy as sq
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

print(f"scanpy version: {sc.__version__}")
print(f"squidpy version: {sq.__version__}")

# %%
SEED = 42
np.random.seed(SEED)

sc.settings.verbosity = 2
sc.settings.set_figure_params(dpi=100, facecolor='white', frameon=False)

PROJECT_ROOT = Path("/Users/sriharshameghadri/randomAIProjects/kaggle/medGemma")
OUTPUT_DIR = PROJECT_ROOT / "outputs"
OUTPUT_DIR.mkdir(exist_ok=True)

# %%
h5ad_path = OUTPUT_DIR / "processed_visium.h5ad"

if not h5ad_path.exists():
    raise FileNotFoundError(
        f"Processed data not found at {h5ad_path}.\n"
        "Please run notebook 01_spatial_analysis.ipynb first."
    )

adata = sc.read_h5ad(h5ad_path)
print(f"Loaded: {adata.shape}")
print(f"Clusters: {adata.obs['leiden'].nunique()}")

# %% [markdown]
# ## 1. Define Gene Signatures
# We define robust signatures for key breast cancer microenvironment components.

# %%
# Define gene signatures
signatures = {
    'Luminal_Epithelial': ['KRT8', 'KRT18', 'ESR1', 'PGR', 'ERBB2', 'GATA3', 'FOXA1', 'MUC1'],
    'Basal_Epithelial': ['KRT5', 'KRT14', 'KRT17', 'TP63', 'EGFR'],
    'T_Cell': ['CD3D', 'CD3E', 'CD8A', 'CD4', 'FOXP3', 'IL2RA'],
    'B_Plasma_Cell': ['CD79A', 'CD19', 'MS4A1', 'MZB1', 'SDC1', 'IGHA1', 'IGHG1'],
    'Macrophage': ['CD68', 'CD163', 'CSF1R', 'FCGR3A', 'ITGAM'],
    'Fibroblast': ['COL1A1', 'COL1A2', 'ACTA2', 'FAP', 'PDGFRA', 'VIM'],
    'Endothelial': ['PECAM1', 'VWF', 'CDH5', 'ENG', 'FLT1']
}

# Ensure genes are present in the dataset
available_signatures = {}
for name, genes in signatures.items():
    valid_genes = [g for g in genes if g in adata.var_names]
    available_signatures[name] = valid_genes
    print(f"{name}: {len(valid_genes)}/{len(genes)} genes found.")

# %% [markdown]
# ## 2. Score Gene Signatures
# We use `sc.tl.score_genes` to evaluate the relative expression of each signature across spots.

# %%
# Calculate signature scores
for name, genes in available_signatures.items():
    if len(genes) > 0:
        # Score genes
        sc.tl.score_genes(adata, gene_list=genes, score_name=f'{name}_score')
        
# Display a sample of the scores
score_columns = [f'{name}_score' for name in available_signatures.keys() if len(available_signatures[name]) > 0]
adata.obs[score_columns].head()

# %% [markdown]
# ## 3. Spatial Visualization of Signatures

# %%
library_id = list(adata.uns['spatial'].keys())[0]

# Plot signatures spatially
sc.pl.spatial(
    adata,
    library_id=library_id,
    color=score_columns,
    cmap='viridis',
    size=1.3,
    ncols=3,
    show=False
)
plt.tight_layout()
plt.savefig(OUTPUT_DIR / 'spatial_signatures.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 4. Define Co-localization & Interfaces
# By using continuous scores, we can identify true "tumor-immune" interfaces: spots that show high enrichment for BOTH Luminal Epithelial and Immune (e.g., T-cell / B-cell) signatures simultaneously.

# %%
# Normalize scores to 0-1 for easier comparison
for col in score_columns:
    col_min = adata.obs[col].min()
    col_max = adata.obs[col].max()
    adata.obs[f'{col}_norm'] = (adata.obs[col] - col_min) / (col_max - col_min)

norm_columns = [f'{col}_norm' for col in score_columns]

# Define interface as spots with > 60th percentile score for both Luminal and any Immune signature
lum_thresh = adata.obs['Luminal_Epithelial_score_norm'].quantile(0.6)
immune_score = adata.obs[['T_Cell_score_norm', 'B_Plasma_Cell_score_norm', 'Macrophage_score_norm']].max(axis=1)
imm_thresh = immune_score.quantile(0.6)

adata.obs['Tumor_Immune_Interface'] = (adata.obs['Luminal_Epithelial_score_norm'] > lum_thresh) & (immune_score > imm_thresh)
adata.obs['Tumor_Immune_Interface'] = adata.obs['Tumor_Immune_Interface'].astype('category')

sc.pl.spatial(
    adata,
    library_id=library_id,
    color='Tumor_Immune_Interface',
    palette=['lightgray', 'red'],
    title='Tumor-Immune Interface (Intra-spot Co-enrichment)',
    size=1.3,
    show=False
)
plt.savefig(OUTPUT_DIR / 'tumor_immune_interface.png', dpi=150, bbox_inches='tight')
plt.show()

interface_spots = adata.obs['Tumor_Immune_Interface'].sum()
print(f"Spots at Tumor-Immune Interface: {interface_spots} ({interface_spots/adata.n_obs*100:.1f}%)")

# %% [markdown]
# ## 5. Export Annotated Data
# Save the signature-annotated data and a summary JSON for MedGemma.

# %%
annotated_h5ad = OUTPUT_DIR / "annotated_visium.h5ad"
adata.write(annotated_h5ad)
print(f"Annotated data saved: {annotated_h5ad}")

import json

# Extract regional signature profiles (mean scores per Leiden cluster)
cluster_profiles = {}
for cluster in sorted(adata.obs['leiden'].unique()):
    cluster_spots = adata.obs[adata.obs['leiden'] == cluster]
    profile = {sig: float(cluster_spots[sig].mean()) for sig in norm_columns}
    cluster_profiles[str(cluster)] = profile

signature_summary = {
    "total_spots": int(adata.n_obs),
    "interface_spots_count": int(interface_spots),
    "interface_spots_percent": float(interface_spots/adata.n_obs*100),
    "mean_signature_scores": {sig: float(adata.obs[sig].mean()) for sig in norm_columns},
    "regional_profiles": cluster_profiles
}

json_path = OUTPUT_DIR / "signature_summary.json"
with open(json_path, 'w') as f:
    json.dump(signature_summary, f, indent=2)

print(f"Signature summary saved: {json_path}")
