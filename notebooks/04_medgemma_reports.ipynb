# %% [markdown]
# # MedGemma-4b Molecular Spatial Summary
#
# Generate assistive molecular summaries from spatial transcriptomics data using MedGemma-4b-it (4-bit quantized).
#
# **Input**: Spatial features + signature scores from Visium data
# **Output**: ~200-word molecular spatial summary (NOT a clinical diagnosis)
# **Model**: MedGemma-4b-it (4-bit quantization for M1 Mac)

# %%
import json
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

print(f"PyTorch version: {torch.__version__}")
print(f"MPS available: {torch.backends.mps.is_available()}")
print(f"Device: {'mps' if torch.backends.mps.is_available() else 'cpu'}")

# %% [markdown]
# ## 1. Load Spatial Analysis Results

# %%
def load_analysis_data():
    """Load spatial features and signature scoring annotations."""
    try:
        with open('../outputs/spatial_features.json', 'r') as f:
            spatial_data = json.load(f)
    except FileNotFoundError:
        spatial_data = None
        
    with open('../outputs/signature_summary.json', 'r') as f:
        signature_data = json.load(f)
    
    return spatial_data, signature_data

spatial_features, signature_summary = load_analysis_data()

print("Signature Summary Loaded:")
print(f"  Total spots: {signature_summary['total_spots']}")
print(f"  Spots at Tumor-Immune Interface: {signature_summary['interface_spots_count']} ({signature_summary['interface_spots_percent']:.1f}%)")

print("\nMean Signature Scores:")
for sig, score in signature_summary['mean_signature_scores'].items():
    print(f"  {sig}: {score:.3f}")

# %% [markdown]
# ## 2. Configure and Load MedGemma-4b Model

# %%
def load_medgemma_model():
    """Load MedGemma-4b-it with 4-bit quantization."""
    model_id = "google/medgemma-4b-it"
    
    quantization_config = BitsAndBytesConfig(
        load_in_4bit=True,
        bnb_4bit_compute_dtype=torch.float16,
        bnb_4bit_quant_type="nf4",
        bnb_4bit_use_double_quant=True
    )
    
    print(f"Loading {model_id} with 4-bit quantization...")
    
    tokenizer = AutoTokenizer.from_pretrained(model_id)
    
    model = AutoModelForCausalLM.from_pretrained(
        model_id,
        quantization_config=quantization_config,
        device_map="auto",
        trust_remote_code=True
    )
    
    print("Model loaded successfully")
    return tokenizer, model

# tokenizer, model = load_medgemma_model()  # Uncomment to execute on valid hardware

# %% [markdown]
# ## 3. Design Molecular Summary Prompt Template
#
# **IMPORTANT:** MedGemma is prompted to act as an *assistive molecular summarizer*, NOT a pathologist making a definitive diagnosis. It describes the data without hallucinating clinical implications that require H&E morphology.

# %%
def create_molecular_prompt(spatial_data, signature_data):
    """Generate molecular summary prompt from spatial analysis."""
    
    total_spots = signature_data['total_spots']
    interface_pct = signature_data['interface_spots_percent']
    
    lum_score = signature_data['mean_signature_scores'].get('Luminal_Epithelial_score_norm', 0)
    immune_t = signature_data['mean_signature_scores'].get('T_Cell_score_norm', 0)
    immune_b = signature_data['mean_signature_scores'].get('B_Plasma_Cell_score_norm', 0)
    fibro = signature_data['mean_signature_scores'].get('Fibroblast_score_norm', 0)
    
    prompt = f"""You are a computational biology assistant reviewing spatial transcriptomics data from a breast cancer biopsy specimen. Based on the following molecular and spatial findings, generate a concise descriptive summary (approximately 200 words). Do NOT attempt to provide a definitive clinical diagnosis or prescribe treatments, as you do not have morphological or clinical context.

SPECIMEN DATA:
- Total analyzed tissue spots: {total_spots}
- Spatial resolution: 10x Genomics Visium (55μm spots, mixed cell populations)
- Tumor-Immune Interface (Intra-spot co-enrichment): {interface_pct:.1f}% of tissue

MEAN MOLECULAR SIGNATURE SCORES (0-1 Normalized):
- Luminal Epithelial: {lum_score:.3f}
- T-Cell: {immune_t:.3f}
- B-Cell/Plasma: {immune_b:.3f}
- Fibroblast: {fibro:.3f}

Generate a molecular summary including:
1. Descriptive overview of the dominant gene signatures
2. Assessment of the tumor-immune spatial interface
3. Potential cellular crosstalk based on co-localization
4. Explicit statement that these findings require morphological validation

MOLECULAR SPATIAL SUMMARY:"""
    
    return prompt

prompt = create_molecular_prompt(spatial_features, signature_summary)
print("Generated Prompt:")
print("=" * 80)
print(prompt)
print("=" * 80)

# %% [markdown]
# ## 4. Generate Molecular Summary

# %%
def generate_report(tokenizer, model, prompt, max_length=400):
    """Generate molecular summary using MedGemma."""
    
    inputs = tokenizer(prompt, return_tensors="pt").to(model.device)
    
    print("Generating molecular summary...")
    
    with torch.no_grad():
        outputs = model.generate(
            **inputs,
            max_new_tokens=max_length,
            temperature=0.7,
            top_p=0.9,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )
    
    full_output = tokenizer.decode(outputs[0], skip_special_tokens=True)
    report = full_output.split("MOLECULAR SPATIAL SUMMARY:")[-1].strip()
    return report

# molecular_summary = generate_report(tokenizer, model, prompt)
# print(molecular_summary)

# %% [markdown]
# ## 5. Save Report

# %%
def save_report(report, signature_data, output_dir="../outputs"):
    """Save molecular summary as TXT."""
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
    txt_path = f"{output_dir}/molecular_summary_{timestamp}.txt"
    with open(txt_path, 'w') as f:
        f.write("SPATIAL TRANSCRIPTOMICS MOLECULAR SUMMARY\n")
        f.write("=" * 80 + "\n\n")
        f.write(report)
        f.write("\n" + "=" * 80 + "\n")
    print(f"Report saved: {txt_path}")
    return txt_path

# save_report(molecular_summary, signature_summary)
